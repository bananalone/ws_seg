# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-8e0d21900b6a> in <module>()
#       2 import matplotlib.pyplot as plt
#       3 import os
# ----> 4 import cv2
#
# ModuleNotFoundError: No module named 'cv2'

# %%
from GradCAM import GradCam, cam2img
from ../models/ResNet import ClsResNet
# Out:
#   File "<ipython-input-3-c8bbd6407f79>", line 2
#     from ../models/ResNet import ClsResNet
#            ^
# SyntaxError: invalid syntax

# %%
import torch
from torchvision.models import vgg16, resnet50

# %%
vgg = vgg16(pretrained=True)
resnet = resnet50(pretrained=True)

# %%
grad_cam = GradCam(resnet, "layer4")

# %%
img_path = "../images/4_yyc_0006.jpg"
mask_path = "../images/4_yyc_0006_label.png"
ship = 510

# %%
img = plt.imread(img_path)
plt.imshow(img)

# %%
mask = plt.imread(mask_path)
plt.imshow(mask)

# %%
img.shape
# Out:
# (256, 256, 3)

# %%
ipt = np.transpose(img, (2, 0, 1))
ipt = np.array([ipt])

# %%
ipt = torch.Tensor(ipt)

# %%
ipt.shape
# Out:
# torch.Size([1, 3, 256, 256])

# %%
cam = grad_cam(ipt, target_class=ship)

# %%
plt.imshow(cam)

# %%
cam.shape
# Out:
# (256, 256)

# %%
plt.imshow(cam2img(img, cam))
